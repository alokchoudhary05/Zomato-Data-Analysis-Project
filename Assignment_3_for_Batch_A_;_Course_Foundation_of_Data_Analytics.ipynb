# %% [markdown]
# <a href="https://colab.research.google.com/github/alokchoudhary05/alokchoudhary/blob/main/Assignment_3_for_Batch_A_%3B_Course_Foundation_of_Data_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Assignment 3**
#   ## **Course: Foundation of Data Analytics**

# %% [markdown]
# ### **Name - Alok Kumar Choudhary**
# #### Course:- BSC{CSDA}-Batch-A {Indian Institute Of Technology Patna}
# #### Roll no:- 2312rec77
# #### Assignment 3 Colab Link:- https://colab.research.google.com/drive/1TJ-ckAdGfz2gBHRN9yoWHmr6ud0GoGOc?usp=sharing

# %% [markdown]
# # Questions
#
# #### Download two datasets(in .csv format) that were not used previously in assignments. Describe
#
# #### Note: Use Kaggle or UCI Machine Learning Repository.
#
# 1.	About Dataset (Example: Iris data is about flower and their parts. Use of this data.)
# 2.	Number of records
# 3.	Number of columns and describe all.
# 4.	Check and remove NULL values using dropna() and fillna() (with mean, median, and mode).
# 5.	Normalize data in the range 0 to 1
# 6.	Draw Line Plots and Scatter Plots to analyze the relationship between columns. Describe observations from both plots.
# 7.	Draw Boxplots to display data distribution and detect outliers in data.
# 8.	Suggest additional features (columns) that may increase the effectiveness of the dataset.
# Hint: First, make a question about what u want to solve using the dataset. Then suggest.

# %% [markdown]
# ---

# %% [markdown]
# ![Zomatooooo.png](data:image/png;base64,...)

# %% [markdown]
# # **Solving Questions on the First Dataset.**
#
# ### I'm using Zomato Dataset .
#  Here link of dataset - https://www.kaggle.com/datasets/rajeshrampure/zomato-dataset

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Data Sets/zomato.csv")
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
df.shape
# Out:
# (51717, 17)

# %%
## Find number of records in the dataset

num_records = len(df)
print("Number of records:", num_records)
# Out:
# Number of records: 51717

# %%
## Find number of columns and describe the dataset

num_columns = len(df.columns)
print("Number of columns:", num_columns)

# Describe all columns
df.describe()
# Out:
# Number of columns: 17
#               votes
# count  51717.000000
# mean     283.697527
# std      803.838853
# min        0.000000
# 25%        7.000000
# 50%       41.000000
# 75%      198.000000
# max    16832.000000

# %%
# Droping unnecessary columns
df.drop(columns=['url','reviews_list','menu_item','dish_liked','cuisines','phone','address','location'],inplace=True)
df.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'votes', 'rest_type',
#        'approx_cost(for two people)', 'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
# Droping duplicates
df.drop_duplicates(ignore_index=True,inplace=True)

# %%
# Renaming columns
df.rename(columns={'approx_cost(for two people)':'_2platescost','listed_in(city)':'location','name':'restaurants'},inplace=True)
df.head()
# Out:
#              restaurants online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#              rest_type _2platescost listed_in(type)      location
# 0        Casual Dining          800          Buffet  Banashankari
# 1        Casual Dining          800          Buffet  Banashankari
# 2  Cafe, Casual Dining          800          Buffet  Banashankari
# 3          Quick Bites          300          Buffet  Banashankari
# 4        Casual Dining          600          Buffet  Banashankari

# %%
# Remove NULL values using dropna()
df=df.dropna()

# %%
# Fill NULL values with mean, median, and mode
df_mean = df.fillna(df.mean(), inplace=True)
df_median = df.fillna(df.median(), inplace=True)
df_mode = df.fillna(df.mode().iloc[0], inplace=True)
# Out:
# <ipython-input-38-a2016065f701>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_mean = df.fillna(df.mean(), inplace=True)
# <ipython-input-38-a2016065f701>:3: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_median = df.fillna(df.median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# restaurants        0
# online_order       0
# book_table         0
# rate               0
# votes              0
# rest_type          0
# _2platescost       0
# listed_in(type)    0
# location           0
# dtype: int64

# %%
# Check if DataFrame has non-numeric columns and exclude them from normalization
numeric_columns = df.select_dtypes(include=['number']).columns
df_numeric = df[numeric_columns]

# Normalize numeric columns using MinMaxScaler
scaler = MinMaxScaler()
df_normalized = pd.DataFrame(scaler.fit_transform(df_numeric), columns=numeric_columns)

# Zomato normalized now contains the normalized values in the range 0 to 1 for numeric columns

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Line Plot
sns.lineplot(x=df.index, y=df['location'])
plt.xlabel('Index')
plt.ylabel('location')
plt.title('Line Plot for location Column')
plt.show()

# %%
# Scatter Plots
sns.scatterplot(x=df.index, y=df['location'], marker='o', color='blue')
plt.xlabel('Index')
plt.ylabel('Column Values')
plt.title('Scatter Plot of location')
plt.show()

# %%
# Scatter Plots
# FINDING TOP 10 rest_type with 2platescost
plt.style.use("Solarize_Light2")
x = df["rest_type"].value_counts().sort_values(ascending=False)[:10]
y = x.index
plt.figure(figsize=(10,6))
sns.scatterplot(x=x,y=y)
plt.xlabel("2platescost")
plt.ylabel("rest_type")
plt.title("Top 10 rest_type - WITH 2platescost",color="black");

# %%
# Boxplots
sns.boxplot(x=df['votes'])
plt.show()

# %%
# Pie plots with counts of online order

plt.style.use("Solarize_Light2")
x = df["online_order"].value_counts()
y = x.index
plt.pie(x=x, labels=y, autopct='%.0f%%')
plt.title("Online order Percentage",color="black");

# %% [markdown]
# # **Suggest 4 Additional Features:**
# # **Rating Analysis:**
#
# ###Question: How do different factors contribute to a restaurant's overall rating?
# ####Suggested Feature 1: Ambiance Rating
# * A column indicating the rating given by customers for the restaurant's ambiance.
# #### Suggested Feature 2: Staff Behavior Rating
# * A column indicating the rating given by customers for the behavior of the restaurant staff.
#
# # **Cost-Effectiveness:**
#
# ###Question: Are there certain types of restaurants or locations that provide more value for money?
# #### Suggested Feature 1: Cost per Vote
# * A column indicating the cost per vote, calculated as the ratio of the '_2platescost' to the number of votes.
# #### Suggested Feature 2: Discount Percentage
# * A column indicating the average discount percentage offered by the restaurant.
#
# #**Popularity Analysis:**
#
# ###Question: What makes a restaurant popular among customers?
# ####Suggested Feature 1: Social Media Presence
# * A column indicating the restaurant's activity on social media platforms.
# ####Suggested Feature 2: Special Events
#  A column indicating whether the restaurant hosts special events or promotions.
#
# #How does the restaurant's online presence impact its popularity?
# ### Suggested Feature: 'online_presence_score'
#
# * Combine the 'online_order' and 'votes' columns to create a score reflecting the online presence and popularity of the restaurant.
# * Assign higher scores to restaurants that accept online orders and have received more votes, indicating a stronger online presence.
# * This score can be useful for ranking and categorizing restaurants based on their online impact.

# %% [markdown]
# # **Thank-You 🙏**

# %% [markdown]
# ---

# %% [markdown]
# ![Diwali.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Solving Questions on the Second Dataset.**
#
# ### I'm using Diwali Sales Dataset 2023 .
#  Here link of dataset - https://www.kaggle.com/datasets/saadharoon27/diwali-sales-dataset?rvi=1

# %% [markdown]
# ## **About Dataset**
# Dataset is all about expenses in Diwali festival and there is showing who is the more shopable in between male and female.This dataset contains sales data for a retail store during the Diwali festival period in India. The data includes information on the products sold, their categories, the sales channels, the dates and times of sale, the sale prices, and the quantities sold.
#
# The purpose of this dataset could be to analyze and understand the spending patterns during the Diwali festival, identify popular products or categories, and potentially optimize inventory and marketing strategies for future festivals.

# %%
# Import Library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Diwali = pd.read_csv("/content/drive/MyDrive/Data Sets/Diwali Sales Data.csv", encoding = "unicode_escape")

# %%
Diwali.shape
# Out:
# (11251, 15)

# %%
Diwali.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
## Find number of records in the dataset

number_records = len(Diwali)
print("Number of records:", number_records)
# Out:
# Number of records: 11251

# %%
## Find number of columns and describe the dataset

number_columns = len(Diwali.columns)
print("Number of columns:", number_columns)

# Describe all columns
Diwali.describe()
# Out:
# Number of columns: 15
#             User_ID           Age  Marital_Status        Orders        Amount  \
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11239.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9453.610858
# std    1.716125e+03     12.754122        0.493632      1.115047   5222.355869
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5443.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000
#
#        Status  unnamed1
# count     0.0       0.0
# mean      NaN       NaN
# std       NaN       NaN
# min       NaN       NaN
# 25%       NaN       NaN
# 50%       NaN       NaN
# 75%       NaN       NaN
# max       NaN       NaN

# %%
# Check for NULL values
Diwali.isnull().sum()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11251
# unnamed1            11251
# dtype: int64

# %%
# Remove NULL values using dropna()
Diwali_cleaned=Diwali.dropna()

# %%
# Fill NULL values with mean, median, and mode
Diwali_mean = Diwali.fillna(Diwali.mean(), inplace=True)
Diwali_median = Diwali.fillna(Diwali.median(), inplace=True)


# Actually in this dataset has not a safficent values for calculate mode in NULL Value.
# For Satisfication I do this code.

mode_df = Diwali.mode()
if not mode_df.empty:
    Diwali_mode = Diwali.fillna(mode_df.iloc[0], inplace=True)
else:
    print("Mode is not available.")
# Out:
# <ipython-input-9-3f6ff3be0918>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Diwali_mean = Diwali.fillna(Diwali.mean(), inplace=True)
# <ipython-input-9-3f6ff3be0918>:3: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Diwali_median = Diwali.fillna(Diwali.median(), inplace=True)

# %%
Diwali.shape
# Out:
# (11251, 15)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# Check if DataFrame has non-numeric columns and exclude them from normalization
numeric_columns = Diwali.select_dtypes(include=['number']).columns
Diwali_numeric = Diwali[numeric_columns]

# Normalize numeric columns using MinMaxScaler
scaler = MinMaxScaler()
Diwali_normalized = pd.DataFrame(scaler.fit_transform(Diwali_numeric), columns=numeric_columns)

# Diwali_normalized now contains the normalized values in the range 0 to 1 for numeric columns
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_data.py:473: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_data.py:474: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'rate' is the column you want to plot
sns.lineplot(x=Diwali.index, y=Diwali['Amount'])

# Set plot labels and title
plt.xlabel('Index')
plt.ylabel('Amount')
plt.title('Line Plot for Amount Column')

# Display the plot
plt.show()

# %%
# Scatter Plot
sns.scatterplot(x=Diwali.index, y=Diwali['Orders'], marker='o', color='blue')
plt.xlabel('Index')
plt.ylabel('Column Values')
plt.title('Scatter Plot of Orders')
plt.show()

# %%
# Scatter Plot

plt.figure(figsize=(10, 6))
sns.scatterplot(data=Diwali, x="Age", y="Orders", hue="Marital_Status", palette="viridis", s=60)
plt.title("Age vs. Orders", fontsize=16)
plt.xlabel("Age", fontsize=14)
plt.ylabel("Orders", fontsize=14)
plt.show()

# %%
# Boxplots
sns.boxplot(x=Diwali['Orders'])
plt.title("Boxplot of Orders")
plt.show()

# %%
# top 10 most sold products

fig1, ax1 = plt.subplots(figsize=(9,6))
Diwali.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='pie')
# Out:
# <Axes: ylabel='Orders'>

# %% [markdown]
# #**Suggest Two Additional Features:**
# Suppose we want to improve the analysis by understanding customer preferences and behavior better. Two additional features could be:
#
# * **Customer Demographics (e.g., age, gender):**
#
# Collecting information about the age and gender of customers can help in tailoring marketing strategies and product offerings to specific demographics, potentially increasing sales.
#
# * **Customer Ratings or Feedback:**
#
# Adding a column for customer ratings or feedback on the purchased products can provide insights into product satisfaction. This information can be used to identify popular products and improve inventory management.
#
# These features could enhance the dataset's effectiveness in understanding customer behavior and making informed business decisions.

# %% [markdown]
# # **Thank-You 🙏**
